# %%
pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 676.9 MB 1.5 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 13.9 MB 37.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 573 kB 64.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 223 kB 74.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.1 MB 52.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.6 MB 52.1 MB/s eta 0:00:01
# ...
# ERROR: tensorflow 2.1.0 has requirement numpy<2.0,>=1.16.0, but you'll have numpy 1.15.4 which is incompatible.
# ERROR: tensorflow 2.1.0 has requirement tensorboard<2.2.0,>=2.1.0, but you'll have tensorboard 2.2.2 which is incompatible.
# ERROR: tensorflow-gpu 2.1.0 has requirement numpy<2.0,>=1.16.0, but you'll have numpy 1.15.4 which is incompatible.
# ERROR: tensorflow-gpu 2.1.0 has requirement tensorboard<2.2.0,>=2.1.0, but you'll have tensorboard 2.2.2 which is incompatible.
# ...

# %%
import os

# %%
! python setup.py develop build
# Out:
# running develop
# running egg_info
# writing ret_benchmark.egg-info/PKG-INFO
# writing dependency_links to ret_benchmark.egg-info/dependency_links.txt
# writing requirements to ret_benchmark.egg-info/requires.txt
# writing top-level names to ret_benchmark.egg-info/top_level.txt
# reading manifest file 'ret_benchmark.egg-info/SOURCES.txt'
# writing manifest file 'ret_benchmark.egg-info/SOURCES.txt'
# running build_ext
# Creating /anaconda/envs/azureml_py36/lib/python3.6/site-packages/ret-benchmark.egg-link (link to .)
# Adding ret-benchmark 0.1 to easy-install.pth file
#
# Installed /mnt/batch/tasks/shared/LS_root/mounts/clusters/zhao/code/Users/zhao.yuan/research-ms-loss-master
# Processing dependencies for ret-benchmark==0.1
# Searching for torchvision==0.3.0
# Best match: torchvision 0.3.0
# Adding torchvision 0.3.0 to easy-install.pth file
#
# Using /anaconda/envs/azureml_py36/lib/python3.6/site-packages
# Searching for torch==1.1.0
# Best match: torch 1.1.0
# ...

# %%
! python tools/main.py --cfg configs/example.yaml
# Out:
# 2020-07-18 14:11:04,280 Train INFO: DATA:
#   NUM_INSTANCES: 5
#   NUM_WORKERS: 8
#   TEST_BATCHSIZE: 256
#   TEST_IMG_SOURCE: resource/datasets/CUB_200_2011/test.txt
#   TRAIN_BATCHSIZE: 80
#   TRAIN_IMG_SOURCE: resource/datasets/CUB_200_2011/train.txt
# INPUT:
#   CROP_SCALE: [0.16, 1]
#   CROP_SIZE: 227
#   FLIP_PROB: 0.5
#   MODE: BGR
#   ORIGIN_SIZE: 256
#   PIXEL_MEAN: [0.40784313725490196, 0.4588235294117647, 0.5019607843137255]
#   PIXEL_STD: [0.00392156862745098, 0.00392156862745098, 0.00392156862745098]
# LOGGER:
#   LEVEL: 20
#   STREAM: stdout
# LOSSES:
#   MARGIN_LOSS:
#     BETA_CONSTANT: False
#     CUTOFF: 0.5
#     N_CLASSES: 100
#     UPPER_CUTOFF: 1.4
#   MULTI_SIMILARITY_LOSS:
#     HARD_MINING: True
#     SCALE_NEG: 40.0
#     SCALE_POS: 2.0
#   NAME: ms_loss
# MODEL:
#   BACKBONE:
#     NAME: bninception
#   DEVICE: cuda
#   HEAD:
#     DIM: 512
#     NAME: linear_norm
#   PRETRAIN: imagenet
#   PRETRIANED_PATH:
#     bninception: ./bn_inception-52deb4733.pth
# ...

# %%
# Out:
# hello world
