# %%
from PIL import Image
import matplotlib.pyplot as plt
import sys
import os

# Image.open()
# print(os.getcwd())
img = Image.open('/mnt/batch/tasks/shared/LS_root/mounts/clusters/yikai/code/Users/yili.lai/recognition/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0001_796111.jpg')
img = img.resize((250,250),Image.BILINEAR)
plt.imshow(img)
plt.show()

# %%
import os
os.system('sh ~/CosFace_pytorch-master GPU')

# %%
! python main.py --batch_size=16
# Out:
# Namespace(batch_size=16, classifier_type='MCP', cuda=True, database='CUB', epochs=30, is_gray=False, log_interval=100, lr=0.1, momentum=0.9, network='sphere20', no_cuda=False, num_class=201, root_path='', save_path='checkpoint/', step_size=[8000, 12000], train_list='/mnt/batch/tasks/shared/LS_root/mounts/clusters/yikai/code/Users/yili.lai/recognition/CUB_200_2011/image_list.txt', weight_decay=0.0005, workers=4)
# length of train Database: 11787
# Number of Identities: 201
# 2020-07-19 21:03:12 Epoch 1 start training
# 2020-07-19 21:03:31 Train Epoch: 1 [1600/11787 (14%)]100, Loss: 23.790410, Elapsed time: 19.0512s(100 iters) Margin: 0.4000, Scale: 30.00
# 2020-07-19 21:03:47 Train Epoch: 1 [3200/11787 (27%)]200, Loss: 19.827788, Elapsed time: 16.4227s(100 iters) Margin: 0.4000, Scale: 30.00
# 2020-07-19 21:04:04 Train Epoch: 1 [4800/11787 (41%)]300, Loss: 19.512244, Elapsed time: 16.6615s(100 iters) Margin: 0.4000, Scale: 30.00
# ...

# %%
! python main.py --batch_size=128 --epochs=100 --network=LResNet50E_IR --lr=0.1 --log_interval=8
# Out:
# Namespace(batch_size=128, classifier_type='MCP', cuda=True, database='CUB', epochs=100, is_gray=False, log_interval=8, lr=0.1, momentum=0.9, network='LResNet50E_IR', no_cuda=False, num_class=200, root_path='', save_path='checkpoint/', step_size=[880, 3520, 6160, 7920], train_list='/mnt/batch/tasks/shared/LS_root/mounts/clusters/yikai/code/Users/yili.lai/recognition/CUB_200_2011/image_list.txt', weight_decay=0.0005, workers=4)
# length of train Database: 11787
# Number of Identities: 200
# 2020-07-20 01:19:13 Epoch 1 start training
# 2020-07-20 01:19:42 Train Epoch: 1 [1024/11787 (9%)]8, Loss: 18.720428, Elapsed time: 29.5524s(8 iters) Margin: 0.4000, Scale: 30.00
# 2020-07-20 01:19:55 Train Epoch: 1 [2048/11787 (17%)]16, Loss: 18.166400, Elapsed time: 12.9758s(8 iters) Margin: 0.4000, Scale: 30.00
# 2020-07-20 01:20:08 Train Epoch: 1 [3072/11787 (26%)]24, Loss: 18.052145, Elapsed time: 12.9958s(8 iters) Margin: 0.4000, Scale: 30.00
# ...

# %%
! python main.py --batch_size=128 --epochs=100 --network=LResNet50E_IR --lr=0.1 --log_interval=8
# Out:
# Namespace(batch_size=128, classifier_type='MCP', cuda=True, database='CUB', epochs=100, is_gray=False, log_interval=8, lr=0.1, momentum=0.9, network='LResNet50E_IR', no_cuda=False, num_class=200, root_path='', save_path='checkpoint/', step_size=[880, 3520, 6160, 7920], train_list='/mnt/batch/tasks/shared/LS_root/mounts/clusters/yikai/code/Users/yili.lai/recognition/CUB_200_2011/image_list_train.txt', weight_decay=0.0005, workers=4)
# length of train Database: 5793
# Number of Identities: 200
# 2020-07-20 18:41:58 Epoch 1 start training
# 2020-07-20 18:42:29 Train Epoch: 1 [1024/5793 (18%)]8, Loss: 18.621046, Elapsed time: 30.0707s(8 iters) Margin: 0.4000, Scale: 30.00
# 2020-07-20 18:42:42 Train Epoch: 1 [2048/5793 (36%)]16, Loss: 18.297239, Elapsed time: 13.2104s(8 iters) Margin: 0.4000, Scale: 30.00
# 2020-07-20 18:42:55 Train Epoch: 1 [3072/5793 (53%)]24, Loss: 18.325430, Elapsed time: 13.2024s(8 iters) Margin: 0.4000, Scale: 30.00
# ...

# %%
! python main.py --batch_size=256 --epochs=100 --network=LResNet50E_IR --lr=0.1 --log_interval=2
# Out:
# Namespace(batch_size=256, classifier_type='MCP', cuda=True, database='CUB', epochs=100, is_gray=False, log_interval=2, lr=0.1, momentum=0.9, network='LResNet50E_IR', no_cuda=False, num_class=200, root_path='', save_path='checkpoint/', step_size=[220, 880, 1760], train_list='/mnt/batch/tasks/shared/LS_root/mounts/clusters/yikai/code/Users/yili.lai/recognition/CUB_200_2011/image_list_train.txt', weight_decay=0.0005, workers=4)
# length of train Database: 5793
# Number of Identities: 200
# 2020-07-21 13:21:23 Epoch 1 start training
# 2020-07-21 13:21:52 Train Epoch: 1 [512/5793 (9%)]2, Loss: 18.138838, Elapsed time: 28.1528s(2 iters) Margin: 0.4000, Scale: 30.00
# 2020-07-21 13:21:55 Train Epoch: 1 [1024/5793 (18%)]4, Loss: 18.291142, Elapsed time: 3.6083s(2 iters) Margin: 0.4000, Scale: 30.00
# 2020-07-21 13:21:59 Train Epoch: 1 [1536/5793 (27%)]6, Loss: 18.223676, Elapsed time: 3.6250s(2 iters) Margin: 0.4000, Scale: 30.00
# ...

# %%
import os
list_1 = os.listdir('Users/hanyuxi.zhou/SoftTriple-master/train')
print(list_1)
